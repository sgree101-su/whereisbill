# %% [markdown]
# # Where is Bill Project

# %%
# Definition of functions
#S.G

def getrecentbill(query):
    url = "https://api.propublica.org/congress/v1/bills/search.json"
    headers={ "X-API-Key": "OL9rTNU3pOCB5FkqOWJH7hMAdmCZLS3GJU5NpLuV" }
    params = {'query' : query}
    response = requests.get(url, headers=headers, params=params)
    bill = response.json()
    bill_data = []
    for i in bill['results'][0]['bills']:
        bills = {}
        bill_data.append(bills)
        bills['bill_id'] = i["bill_id"]
        bills['bill_title'] = i['title']
        bills['latest_major_action_date'] = i['latest_major_action_date']
        bills['latest_major_action'] = i['latest_major_action']        
        
    
    return bill_data

def getmemberbill(ID):
    url = "https://api.propublica.org/congress/v1/members/" + ID + "/bills/introduced.json"
    headers={ "X-API-Key": "OL9rTNU3pOCB5FkqOWJH7hMAdmCZLS3GJU5NpLuV" }
    response = requests.get(url, headers=headers)
    bill = response.json()
    bill_data2 = []
    for i in bill['results'][0]['bills']:
        bills = {}
        bill_data2.append(bills)
        bills['bill_id'] = i["bill_id"]
        bills['bill_title'] = i['title']
        bills['latest_major_action_date'] = i['latest_major_action_date']
        bills['latest_major_action'] = i['latest_major_action']
    
    return bill_data2


def getlegislator(state):
    legislator = pd.read_csv('legislators-current.csv')
    legislator_df = pd.DataFrame({ 'First_Name' : legislator['first_name'], 
                                 'Last_Name' : legislator['last_name'],
                                 'State': legislator['state'],
                                 'Party': legislator['party'],
                                 'Phone': legislator['phone'],
                                 'ID': legislator['bioguide_id']
                               })
    legislator_df = legislator_df[(legislator['state'] == state) & (legislator['type'] == 'sen')]
    return legislator_df

# %%
# Main program
#S.G

import json
import requests
import pandas as pd
import numpy as np

from pprint import pprint
import textwrap

# this turns off warning messages
import warnings
warnings.filterwarnings('ignore')

class color:
   PURPLE = '\033[95m'
   CYAN = '\033[96m'
   DARKCYAN = '\033[36m'
   BLUE = '\033[94m'
   GREEN = '\033[92m'
   YELLOW = '\033[93m'
   RED = '\033[91m'
   BOLD = '\033[1m'
   UNDERLINE = '\033[4m'
   END = '\033[0m'

print('#####Where is Bill?#####')
print('''
  
''')
while True:
    user_input = input("Press 'Enter' to continue or type 'quit' to exit the program: ")
    if user_input == "quit":
        break 
    elif user_input == "":
        query = input('What subjects are you interested in: ')
        bills = getrecentbill(query)
        print("")
        for i in bills:
            print("*****************************")
            print(color.BOLD + "Bill ID:" + color.END, i['bill_id'],)
            print(color.BOLD + "Bill Title:" + color.END, i['bill_title'],)
            print(color.BOLD + "Bill Latest Major Action:" + color.END, i['latest_major_action'],)
            print(color.BOLD + "Bill Latest Major Action Date:" + color.END, i['latest_major_action_date'])
            print("*****************************\n")
        break
# Out:
# #####Where is Bill?#####
#
#
#
# Press 'Enter' to continue or type 'quit' to exit the program:
# What subjects are you interested in: dod
#
# *****************************
# Bill ID: hr2810-115
# Bill Title: To authorize appropriations for fiscal year 2018 for military activities of the Department of Defense and for military construction, to prescribe military personnel strengths for such fiscal year, and for other purposes.
# Bill Latest Major Action: Presented to President.
# Bill Latest Major Action Date: 2017-11-30
# *****************************
#
# *****************************
# Bill ID: s2108-115
# Bill Title: A bill to amend the Harmonized Tariff Schedule of the United States to modify temporarily certain rates of duty.
# Bill Latest Major Action: Read twice and referred to the Committee on Finance.
# Bill Latest Major Action Date: 2017-11-09
# *****************************
#
# *****************************
# Bill ID: hr4074-115
# ...

# %%
  elif user_input == "2":
        state = input('What is your state accronym? (example: NY for New York) ')
        legislator = getlegislator(state)
        print(legislator)
        choices = input('Would you like to save a senator for later use? ')
        if choices == 'yes':
            choice = input("Enter the Senator index id: ")  
            ID = legislator['ID'][(legislator['ID'] == choice)]

    elif user_input == "3":
        saved = input('Would you like to use the previously saved Senator? ')
        if saved == 'yes':
            memberBill = getmemberbill(ID)
        if saved == 'no':
            new = input("Please select the Senator ID")
            memberBill = getmemberbill(new)
        print(memberBill
